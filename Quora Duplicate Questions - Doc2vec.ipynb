# %%
import gensim
import multiprocessing
import os

# %% [markdown]
# # Create Cleaned Data from raw .tsv file

# %%
# files names - if these files and folders don't exist then they are downloaded 
raw_file_name = "quora_duplicate_questions.tsv"
q1_file_name = "cleaned_q1.txt"
q2_file_name = "cleaned_q2.txt"
dup_file_name = "is_duplicate.txt"
questions_folder_name = "cleaned_data"

# file to store hyperparameter tuning numbers
parameters_and_errors_name = "test_parameters_and_errors.csv"# "parameters_and_errors.csv"

# %%
import pandas as pd
import os
import string
import requests

# check whether downloaded data already exists with names provided above
if not os.path.isdir(questions_folder_name) or not os.path.isfile(dup_file_name):
    
    # Download questions file - data set has been changed since first release
    url = 'http://qim.ec.quoracdn.net/quora_duplicate_questions.tsv'
    r = requests.get(url)
    with open(raw_file_name, 'wb') as f:
        f.write(r.content)
    
    # DATA CLEANING WITH PANDAS
    
    # read in file into dataframe
    data = pd.read_csv(raw_file_name, sep='\t')
    # drop rows with null value
    data.dropna(inplace=True)
    # make columns of lower cased words
    data["cleaned_q1"] = data.text1.str.lower()
    data["cleaned_q2"] = data.text2.str.lower()
    # remove punctuation from lower-cased words columns
    data['cleaned_q1'] = data['cleaned_q1'].apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
    data['cleaned_q2'] = data['cleaned_q2'].apply(lambda x:''.join([i for i in x if i not in string.punctuation]))
    # remove the character "\n", which messes up the line delimiters in txt file
    # these only occur ~20 times in the questions
    data["cleaned_q1"] = data['cleaned_q1'].str.replace("\n", "")
    data["cleaned_q2"] = data['cleaned_q2'].str.replace("\n", "")
    # shuffle data before writing to file - this way random sample can be taken from file 
    # simply by choosing first n rows of file
    data = data.sample(frac=1)

    # create directory to hold question data
    if not os.path.exists(questions_folder_name):
        os.makedirs(questions_folder_name)

    # write cleaned text rows to txt files, one line for each sentence
    data["cleaned_q1"].to_csv(questions_folder_name + "/" + q1_file_name, sep='\n', header=False, index=False)
    data["cleaned_q2"].to_csv(questions_folder_name + "/" + q2_file_name, sep='\n', header=False, index=False)
    # write dup values to txt file, one line for each value
    data["duplicate"].to_csv(dup_file_name, sep='\n', header=False, index=False)

    print "Saved file with", len(data), "rows at", raw_file_name
else: 
    print "Directory that should contain data already exists."
# Out:
# Directory that should contain data already exists.

# %% [markdown]
# # Load in data

# %% [markdown]
# ## Input parameters

# %%
# notebook assumes you have a directory "questions_directory" that contains two text files, one for all 
# first questions and one for all second questions, and a file is_dup_file that has one boolean value (0 or 1)
# on each line, one for all ~400,000 document pairs that tells whether questions are duplicates or not

# path to questions directory (contains sorted question text files) and 
# is_dup_file (contains sorted answers about whether question pairs are duplicates)

# These files and directories are created automatically by the above cell
questions_directory = questions_folder_name
is_dup_file = dup_file_name
questions_file_names = [os.path.basename(filename) for filename in os.listdir(questions_directory)]

# %%
questions_file_names
# Out:
# ['cleaned_q1.txt', 'cleaned_q2.txt']

# %% [markdown]
# ## Load in data

# %%
# set number of rows (question pairs) to train on
num_question_pairs = 5000

# %%
# produce logs during training
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
rootLogger = logging.getLogger()
rootLogger.setLevel(logging.INFO)

# %%
# create iterator to run through directory of text files with one sentence per line
from itertools import izip, count

# class that iterates through first "rows" lines of questions list ("rows" is integer)
class LabeledLineSentence(object):
    def __init__(self, dirname, rows=None):
        self.dirname = dirname
        self.rows = rows
    def __iter__(self):
        for filename in os.listdir(self.dirname):
            for uid, text_line in enumerate(open(os.path.join(self.dirname, filename))):
                if self.rows:
                    if uid >= self.rows: 
                        break
            # for uid, line in enumerate(open(os.path.join(self.dirname, filename))):
                yield gensim.models.doc2vec.LabeledSentence(words=text_line.split(), tags=[os.path.basename(filename) + '_%s' % uid])

# make sure using fast version
assert gensim.models.doc2vec.FAST_VERSION > -1
cores = multiprocessing.cpu_count() # number of cores on computer to use for computations

# %%
# load in data into memory - all data combined should only be 200-300 megabytes
# this is done instead of using iterator - makes doing shuffles of data easier

all_docs = []
sentences = LabeledLineSentence(questions_directory, rows=num_question_pairs)
for sentence in sentences:
    all_docs.append(sentence)

print('%d question pairs to train (%d documents total)' % (num_question_pairs, len(all_docs)))
# Out:
# 5000 question pairs to train (10000 documents total)

# %%
# make list of tuples (document1, document2, is_dup) for all num_question_pairs
# the document names come from naming scheme used in LabeledLineSentence class 

doc_names_and_duplicate_class = []
for i, line in enumerate(open(is_dup_file)):
    if i >= num_question_pairs:
        break
    doc_tup = (questions_file_names[0] + "_" + str(i), questions_file_names[1] + "_" + str(i), int(line.strip("\n")))
    doc_names_and_duplicate_class.append(doc_tup)

print len(doc_names_and_duplicate_class), "document pairs to classify"
print "Document pair names and labels contained in doc_names_and_duplicate_class"
# Out:
# 5000 document pairs to classify
# Document pair names and labels contained in doc_names_and_duplicate_class

# %%
doc_names_and_duplicate_class[0]
# Out:
# ('cleaned_q1.txt_0', 'cleaned_q2.txt_0', 1)

# %% [markdown]
# # Evaluate Model

# %%
import numpy as np
from sklearn.metrics import roc_auc_score

def calculate_AUC(model, doc_names_and_duplicate_class): 
    """ Return area under ROC curve for model. This is done by simply taking cosine similarity between 
        document vectors to predict whether they are duplicate questions or not.
    """
    doc_distances = []

    for i in range(len(doc_names_and_duplicate_class)):
        # get word vectors for given pair
        vec1_name = doc_names_and_duplicate_class[i][0]
        vec2_name = doc_names_and_duplicate_class[i][1]
        vec1 = model.docvecs[vec1_name]         
        vec2 = model.docvecs[vec2_name]       
        # take cosine distance between them
        distance = cosine_similarity(vec1, vec2)
        doc_distances.append(distance)

    doc_distances = np.array(doc_distances)
    doc_scores = np.array([x[2] for x in doc_names_and_duplicate_class])
    
    return roc_auc_score(doc_scores, doc_distances)

def cosine_similarity(vec1, vec2): 
    # return cosine angle between numpy vectors v1 and v2
    def unit_vector(vec):
        return vec/np.linalg.norm(vec)
    vec1_u, vec2_u = unit_vector(vec1), unit_vector(vec2)
    return np.dot(vec1_u, vec2_u)

# for timing
from contextlib import contextmanager
from timeit import default_timer
import time 

@contextmanager
def elapsed_timer():
    start = default_timer()
    elapser = lambda: default_timer() - start
    yield lambda: elapser()
    end = default_timer()
    elapser = lambda: end-start

# %% [markdown]
# # Train model

# %%
# initialize Doc2vec model parameters
"""
The documents iterable can be simply a list of TaggedDocument elements, 
but for larger corpora, consider an iterable that streams the documents 
directly from disk/network.

If you don’t supply documents, the model is left uninitialized – 
use if you plan to initialize it in some other way.



dm defines the training algorithm. By default (dm=1), 
    ‘distributed memory’ (PV-DM) is used. Otherwise, distributed bag of words (PV-DBOW) is employed.

size is the dimensionality of the feature vectors.

window is the maximum distance between the predicted word and context words used for prediction within a document.

alpha is the initial learning rate (will linearly drop to zero as training progresses).

seed = for the random number generator. Note that for a fully deterministically-reproducible run, 
    you must also limit the model to a single worker thread, to eliminate ordering jitter from 
    OS thread scheduling. (In Python 3, reproducibility between interpreter launches also 
    requires use of the PYTHONHASHSEED environment variable to control hash randomization.)

min_count = ignore all words with total frequency lower than this.

max_vocab_size = limit RAM during vocabulary building; if there are more unique words 
                 than this, then prune the infrequent ones. Every 10 million word types 
                 need about 1GB of RAM. Set to None for no limit (default).

sample = threshold for configuring which higher-frequency words are randomly downsampled;
        default is 0 (off), useful value is 1e-5.
        
workers = use this many worker threads to train the model (=faster training with multicore machines).

iter = number of iterations (epochs) over the corpus. The default inherited from Word2Vec is 5, 
        but values of 10 or 20 are common in published ‘Paragraph Vector’ experiments.

hs = if 1 (default), hierarchical sampling will be used for model training (else set to 0).

negative = if > 0, negative sampling will be used, the int for negative specifies how many 
            “noise words” should be drawn (usually between 5-20).

dm_mean = if 0 (default), use the sum of the context word vectors. If 1, use the mean. 
            Only applies when dm is used in non-concatenative mode.

dm_concat = if 1, use concatenation of context vectors rather than sum/average; default is 0 (off). 
                Note concatenation results in a much-larger model, as the input is no longer the size of 
                one (sampled or arithmatically combined) word vector, but the size of the tag(s) and all 
                words in the context strung together.

dm_tag_count = expected constant number of document tags per document, when using dm_concat mode; default is 1.

dbow_words if set to 1 trains word-vectors (in skip-gram fashion) simultaneous with DBOW doc-vector training; 
            default is 0 (faster training of doc-vectors only).

"""


# set model parameters parameters

parameters_dict = {

'documents' : all_docs,
'dm' : 0, # use bag-of-words (dbow) model; 1 uses embedding (dmpv) model
'size' : 200, # size of word/doc vectors
'window' : 15, # # max distance between word and neighbor word for word embeddings
'alpha' : .025, # learning rate - use rate in paper
'min_alpha' : 0.0001, # rate from paper
'min_count' : 5, # ignore words with count less than this
'sample' : 1e-5, # how to configure downsampling for high frequency words
'workers' : cores, # number of cores to use
'hs' : 0, # use negative sampling
'negative' : 5, # used in negative sampling
'dbow_words' : 1, # trains word vectors in addition to document vectors in dbow model
'iter' : 3 # recommended number of epochs is ~20 for dbow model on question comparison   

}

# %% [markdown]
# ## Create parameters for grid search

# %%
# create list of parameters to use in model
dms = [0]
sizes = [300]
windows = [5, 15]
alphas = [0.025]
min_alphas = [0.0001]
min_counts = [1, 5]
samples = [1e-5, 0.5e-5, 1e-6]
workers_s = [cores]
hs_s = [0]
negatives = [5]
dbow_words_s = [1]
iters = [150]

# %%
# run through all parameters and record error rate of each one
from itertools import product

# create list to score ROC AUC scores and their model parameters
params_and_errors = []
# create iterable of all combinations of parameters
params_product = product(dms, sizes, windows, alphas, min_alphas, 
                        min_counts, samples, workers_s, hs_s, negatives, 
                        dbow_words_s, iters)
parameters = [x for x in params_product]

# %%
print "Starting first run of", len(parameters), "runs"
total_time = 0
for run_number, pars in enumerate(parameters): 
    params = {'dm':pars[0], 'size':pars[1], 'window':pars[2], 
              'alpha':pars[3], 'min_alpha':pars[4], 'min_count':pars[5],
              'sample':pars[6], 'workers':pars[7], 'hs':pars[8],
              'negative':pars[9], 'dbow_words':pars[10], 'iter':pars[11]}
    with elapsed_timer() as elapsed:
        model = gensim.models.doc2vec.Doc2Vec(documents=all_docs, **params)
        AUC_value = calculate_AUC(model, doc_names_and_duplicate_class)
        params_and_errors.append((params, AUC_value))
        duration = '%.1f' % elapsed()
        total_time += float(duration)
        print 
        print "Completed run number", run_number + 1, "of", len(parameters), "runs total"
        print "AUC score:", round(AUC_value, 4)
        print "Training for this run took", round(float(duration)/60.,1), "minutes"

best_AUC = max([x[1] for x in params_and_errors])
print
print
print "Total training time for all runs:", round(float(total_time)/3600.,2), "hours"
print "Best AUC value:", round(best_AUC, 6)
print "Paramters for best AUC value:", [x[0] for x in params_and_errors if x[1] == best_AUC][0]

# convert params and errors into easy-to-read pandas dataframe
params_df = pd.DataFrame([x[0] for x in params_and_errors])
params_df["AUC"] = pd.Series([x[1] for x in params_and_errors])
params_df.sort_values("AUC", ascending=False, inplace=True)

# write parameter values to csv - append if this csv already exists
header=True
if os.path.isfile(parameters_and_errors_name):
    header=False
params_df.to_csv(parameters_and_errors_name, header=header, index=False, mode="a")
# Out:
# 2017-02-23 14:14:12,858 : INFO : collecting all words and their counts
# 2017-02-23 14:14:12,883 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-02-23 14:14:13,062 : INFO : collected 10735 word types and 10000 unique tags from a corpus of 10000 examples and 108824 words
# 2017-02-23 14:14:13,067 : INFO : Loading a fresh vocabulary
# Starting first run of 12 runs
# 2017-02-23 14:14:13,161 : INFO : min_count=1 retains 10735 unique words (100% of original 10735, drops 0)
# 2017-02-23 14:14:13,162 : INFO : min_count=1 leaves 108824 word corpus (100% of original 108824, drops 0)
# 2017-02-23 14:14:13,279 : INFO : deleting the raw counts dictionary of 10735 items
# 2017-02-23 14:14:13,280 : INFO : sample=1e-05 downsamples 3746 most-common words
# 2017-02-23 14:14:13,282 : INFO : downsampling leaves estimated 26577 word corpus (24.4% of prior 108824)
# 2017-02-23 14:14:13,286 : INFO : estimated required memory for 10735 words and 300 dimensions: 45131500 bytes
# 2017-02-23 14:14:13,373 : INFO : resetting layer weights
# 2017-02-23 14:14:14,156 : INFO : training model with 4 workers on 10735 vocabulary and 300 features, using sg=1 hs=0 sample=1e-05 negative=5 window=5
# 2017-02-23 14:14:14,157 : INFO : expecting 10000 sentences, matching count from corpus used for vocabulary survey
# 2017-02-23 14:14:15,401 : INFO : PROGRESS: at 0.55% examples, 24621 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:16,614 : INFO : PROGRESS: at 1.35% examples, 30171 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:17,630 : INFO : PROGRESS: at 2.14% examples, 33955 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:18,651 : INFO : PROGRESS: at 3.00% examples, 36718 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:19,823 : INFO : PROGRESS: at 3.80% examples, 36849 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:20,871 : INFO : PROGRESS: at 4.72% examples, 38617 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:22,023 : INFO : PROGRESS: at 5.51% examples, 38503 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:23,027 : INFO : PROGRESS: at 6.25% examples, 38709 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:24,032 : INFO : PROGRESS: at 7.10% examples, 39534 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:25,228 : INFO : PROGRESS: at 7.96% examples, 39518 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:26,254 : INFO : PROGRESS: at 8.82% examples, 40048 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:27,441 : INFO : PROGRESS: at 9.68% examples, 40002 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:28,491 : INFO : PROGRESS: at 10.59% examples, 40565 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:29,640 : INFO : PROGRESS: at 11.39% examples, 40377 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:30,640 : INFO : PROGRESS: at 12.19% examples, 40585 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:31,656 : INFO : PROGRESS: at 12.92% examples, 40540 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:32,713 : INFO : PROGRESS: at 13.78% examples, 40779 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:33,798 : INFO : PROGRESS: at 14.57% examples, 40731 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:34,849 : INFO : PROGRESS: at 15.37% examples, 40763 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:35,868 : INFO : PROGRESS: at 16.23% examples, 41040 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:36,936 : INFO : PROGRESS: at 17.02% examples, 41023 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:37,998 : INFO : PROGRESS: at 17.82% examples, 41041 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:39,035 : INFO : PROGRESS: at 18.67% examples, 41210 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:40,123 : INFO : PROGRESS: at 19.47% examples, 41169 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:41,165 : INFO : PROGRESS: at 20.27% examples, 41196 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:42,206 : INFO : PROGRESS: at 21.12% examples, 41338 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:43,261 : INFO : PROGRESS: at 21.92% examples, 41339 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:44,343 : INFO : PROGRESS: at 22.72% examples, 41302 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:45,455 : INFO : PROGRESS: at 23.64% examples, 41450 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:46,548 : INFO : PROGRESS: at 24.43% examples, 41400 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:47,573 : INFO : PROGRESS: at 25.23% examples, 41433 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:48,578 : INFO : PROGRESS: at 25.96% examples, 41394 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:49,661 : INFO : PROGRESS: at 26.82% examples, 41457 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:50,801 : INFO : PROGRESS: at 27.62% examples, 41360 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:51,808 : INFO : PROGRESS: at 28.47% examples, 41498 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:52,840 : INFO : PROGRESS: at 29.27% examples, 41514 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:53,970 : INFO : PROGRESS: at 30.06% examples, 41434 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:55,043 : INFO : PROGRESS: at 30.98% examples, 41583 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:14:56,177 : INFO : PROGRESS: at 31.78% examples, 41498 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:57,235 : INFO : PROGRESS: at 32.69% examples, 41646 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:58,384 : INFO : PROGRESS: at 33.49% examples, 41556 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:14:59,448 : INFO : PROGRESS: at 34.41% examples, 41689 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:00,599 : INFO : PROGRESS: at 35.21% examples, 41596 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:01,658 : INFO : PROGRESS: at 36.12% examples, 41733 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:02,824 : INFO : PROGRESS: at 36.92% examples, 41630 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:03,848 : INFO : PROGRESS: at 37.84% examples, 41787 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:05,039 : INFO : PROGRESS: at 38.63% examples, 41659 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:06,041 : INFO : PROGRESS: at 39.55% examples, 41826 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:07,261 : INFO : PROGRESS: at 40.35% examples, 41685 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:08,516 : INFO : PROGRESS: at 41.33% examples, 41705 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:09,741 : INFO : PROGRESS: at 42.31% examples, 41757 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:10,997 : INFO : PROGRESS: at 43.29% examples, 41781 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:12,001 : INFO : PROGRESS: at 44.21% examples, 41926 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:13,212 : INFO : PROGRESS: at 45.00% examples, 41808 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:14,220 : INFO : PROGRESS: at 45.74% examples, 41776 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:15,269 : INFO : PROGRESS: at 46.53% examples, 41773 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:16,331 : INFO : PROGRESS: at 47.33% examples, 41762 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:17,389 : INFO : PROGRESS: at 48.06% examples, 41701 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:18,522 : INFO : PROGRESS: at 48.92% examples, 41697 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:19,604 : INFO : PROGRESS: at 49.78% examples, 41724 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:20,720 : INFO : PROGRESS: at 50.63% examples, 41732 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:21,732 : INFO : PROGRESS: at 51.43% examples, 41751 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:22,765 : INFO : PROGRESS: at 52.23% examples, 41759 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:23,898 : INFO : PROGRESS: at 53.08% examples, 41756 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:24,965 : INFO : PROGRESS: at 53.94% examples, 41791 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:26,088 : INFO : PROGRESS: at 54.80% examples, 41790 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:27,175 : INFO : PROGRESS: at 55.66% examples, 41812 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:28,276 : INFO : PROGRESS: at 56.51% examples, 41825 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:29,298 : INFO : PROGRESS: at 57.31% examples, 41835 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:30,317 : INFO : PROGRESS: at 58.10% examples, 41846 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:31,427 : INFO : PROGRESS: at 58.96% examples, 41856 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:32,453 : INFO : PROGRESS: at 59.76% examples, 41865 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:33,491 : INFO : PROGRESS: at 60.55% examples, 41865 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:34,492 : INFO : PROGRESS: at 61.35% examples, 41885 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:35,535 : INFO : PROGRESS: at 62.14% examples, 41885 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:36,570 : INFO : PROGRESS: at 62.94% examples, 41890 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:37,575 : INFO : PROGRESS: at 63.74% examples, 41907 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:38,600 : INFO : PROGRESS: at 64.53% examples, 41916 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:39,625 : INFO : PROGRESS: at 65.33% examples, 41925 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:40,685 : INFO : PROGRESS: at 66.12% examples, 41917 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:41,750 : INFO : PROGRESS: at 66.98% examples, 41945 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:42,783 : INFO : PROGRESS: at 67.78% examples, 41949 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:43,832 : INFO : PROGRESS: at 68.57% examples, 41946 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:44,909 : INFO : PROGRESS: at 69.43% examples, 41967 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:45,946 : INFO : PROGRESS: at 70.23% examples, 41973 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:46,979 : INFO : PROGRESS: at 71.02% examples, 41975 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:48,097 : INFO : PROGRESS: at 71.88% examples, 41976 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:49,095 : INFO : PROGRESS: at 72.67% examples, 41992 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:50,135 : INFO : PROGRESS: at 73.47% examples, 41993 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:51,245 : INFO : PROGRESS: at 74.33% examples, 41999 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:52,269 : INFO : PROGRESS: at 75.12% examples, 42006 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:53,282 : INFO : PROGRESS: at 75.92% examples, 42016 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:54,417 : INFO : PROGRESS: at 76.78% examples, 42006 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:55,487 : INFO : PROGRESS: at 77.64% examples, 42029 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:56,632 : INFO : PROGRESS: at 78.49% examples, 42018 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:57,676 : INFO : PROGRESS: at 79.35% examples, 42047 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:15:58,692 : INFO : PROGRESS: at 80.14% examples, 42059 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:15:59,789 : INFO : PROGRESS: at 80.94% examples, 42037 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:00,810 : INFO : PROGRESS: at 81.74% examples, 42042 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:01,843 : INFO : PROGRESS: at 82.59% examples, 42075 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:02,959 : INFO : PROGRESS: at 83.39% examples, 42043 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:03,986 : INFO : PROGRESS: at 84.25% examples, 42081 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:04,995 : INFO : PROGRESS: at 85.04% examples, 42091 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:06,106 : INFO : PROGRESS: at 85.84% examples, 42063 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:07,139 : INFO : PROGRESS: at 86.69% examples, 42095 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:08,158 : INFO : PROGRESS: at 87.49% examples, 42101 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:09,283 : INFO : PROGRESS: at 88.29% examples, 42071 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:10,294 : INFO : PROGRESS: at 89.14% examples, 42112 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:11,305 : INFO : PROGRESS: at 89.94% examples, 42120 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:12,436 : INFO : PROGRESS: at 90.74% examples, 42087 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:13,434 : INFO : PROGRESS: at 91.59% examples, 42130 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:14,499 : INFO : PROGRESS: at 92.39% examples, 42120 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:15,625 : INFO : PROGRESS: at 93.19% examples, 42089 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:16,690 : INFO : PROGRESS: at 94.10% examples, 42135 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:17,849 : INFO : PROGRESS: at 94.90% examples, 42094 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:18,885 : INFO : PROGRESS: at 95.82% examples, 42149 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:20,027 : INFO : PROGRESS: at 96.61% examples, 42112 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:21,054 : INFO : PROGRESS: at 97.47% examples, 42143 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:22,232 : INFO : PROGRESS: at 98.33% examples, 42123 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:23,239 : INFO : PROGRESS: at 99.19% examples, 42158 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:24,098 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-02-23 14:16:24,134 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-02-23 14:16:24,154 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-02-23 14:16:24,162 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-02-23 14:16:24,163 : INFO : training on 16323600 raw words (5485778 effective words) took 130.0s, 42202 effective words/s
# 2017-02-23 14:16:25,638 : INFO : collecting all words and their counts
# 2017-02-23 14:16:25,639 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-02-23 14:16:25,765 : INFO : collected 10735 word types and 10000 unique tags from a corpus of 10000 examples and 108824 words
# 2017-02-23 14:16:25,766 : INFO : Loading a fresh vocabulary
# Completed run number 1 of 12 runs total
# AUC score: 0.7127
# Training for this run took 2.2 minutes
# 2017-02-23 14:16:26,502 : INFO : min_count=1 retains 10735 unique words (100% of original 10735, drops 0)
# 2017-02-23 14:16:26,504 : INFO : min_count=1 leaves 108824 word corpus (100% of original 108824, drops 0)
# 2017-02-23 14:16:26,592 : INFO : deleting the raw counts dictionary of 10735 items
# 2017-02-23 14:16:26,594 : INFO : sample=5e-06 downsamples 5947 most-common words
# 2017-02-23 14:16:26,594 : INFO : downsampling leaves estimated 19732 word corpus (18.1% of prior 108824)
# 2017-02-23 14:16:26,596 : INFO : estimated required memory for 10735 words and 300 dimensions: 45131500 bytes
# 2017-02-23 14:16:26,663 : INFO : resetting layer weights
# 2017-02-23 14:16:27,291 : INFO : training model with 4 workers on 10735 vocabulary and 300 features, using sg=1 hs=0 sample=5e-06 negative=5 window=5
# 2017-02-23 14:16:27,292 : INFO : expecting 10000 sentences, matching count from corpus used for vocabulary survey
# 2017-02-23 14:16:28,538 : INFO : PROGRESS: at 0.80% examples, 28686 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:29,750 : INFO : PROGRESS: at 1.78% examples, 32414 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:30,967 : INFO : PROGRESS: at 2.76% examples, 33532 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:32,182 : INFO : PROGRESS: at 3.74% examples, 34164 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:33,428 : INFO : PROGRESS: at 4.72% examples, 34339 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:34,631 : INFO : PROGRESS: at 5.70% examples, 34662 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:35,842 : INFO : PROGRESS: at 6.67% examples, 34826 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:37,052 : INFO : PROGRESS: at 7.66% examples, 34991 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:38,056 : INFO : PROGRESS: at 8.57% examples, 35515 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:39,182 : INFO : PROGRESS: at 9.37% examples, 35134 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:40,196 : INFO : PROGRESS: at 10.29% examples, 35563 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:41,317 : INFO : PROGRESS: at 11.08% examples, 35235 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:42,323 : INFO : PROGRESS: at 12.00% examples, 35585 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:43,490 : INFO : PROGRESS: at 12.80% examples, 35219 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:44,494 : INFO : PROGRESS: at 13.72% examples, 35555 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:45,620 : INFO : PROGRESS: at 14.51% examples, 35307 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:46,658 : INFO : PROGRESS: at 15.43% examples, 35524 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:47,768 : INFO : PROGRESS: at 16.23% examples, 35334 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:48,804 : INFO : PROGRESS: at 17.14% examples, 35539 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:49,885 : INFO : PROGRESS: at 17.94% examples, 35399 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:50,954 : INFO : PROGRESS: at 18.86% examples, 35541 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:52,025 : INFO : PROGRESS: at 19.66% examples, 35437 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:16:53,095 : INFO : PROGRESS: at 20.57% examples, 35557 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:54,160 : INFO : PROGRESS: at 21.37% examples, 35459 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:55,239 : INFO : PROGRESS: at 22.29% examples, 35556 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:56,297 : INFO : PROGRESS: at 23.08% examples, 35486 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:57,372 : INFO : PROGRESS: at 24.00% examples, 35576 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:58,425 : INFO : PROGRESS: at 24.80% examples, 35516 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:16:59,516 : INFO : PROGRESS: at 25.72% examples, 35582 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:00,558 : INFO : PROGRESS: at 26.51% examples, 35531 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:01,660 : INFO : PROGRESS: at 27.43% examples, 35578 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:02,687 : INFO : PROGRESS: at 28.23% examples, 35549 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:03,793 : INFO : PROGRESS: at 29.14% examples, 35592 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:04,810 : INFO : PROGRESS: at 29.94% examples, 35569 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:05,836 : INFO : PROGRESS: at 30.80% examples, 35616 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:06,944 : INFO : PROGRESS: at 31.66% examples, 35590 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:07,962 : INFO : PROGRESS: at 32.51% examples, 35640 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:08,968 : INFO : PROGRESS: at 33.31% examples, 35628 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:09,992 : INFO : PROGRESS: at 34.10% examples, 35603 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:11,021 : INFO : PROGRESS: at 34.96% examples, 35641 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:12,113 : INFO : PROGRESS: at 35.82% examples, 35624 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:13,166 : INFO : PROGRESS: at 36.67% examples, 35641 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:14,257 : INFO : PROGRESS: at 37.53% examples, 35629 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:15,299 : INFO : PROGRESS: at 38.39% examples, 35650 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:16,379 : INFO : PROGRESS: at 39.25% examples, 35644 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:17,441 : INFO : PROGRESS: at 40.10% examples, 35655 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:18,528 : INFO : PROGRESS: at 40.96% examples, 35650 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:19,570 : INFO : PROGRESS: at 41.82% examples, 35670 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:20,643 : INFO : PROGRESS: at 42.67% examples, 35665 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:21,653 : INFO : PROGRESS: at 43.47% examples, 35661 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:22,681 : INFO : PROGRESS: at 44.33% examples, 35691 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:23,781 : INFO : PROGRESS: at 45.19% examples, 35670 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:24,813 : INFO : PROGRESS: at 46.04% examples, 35691 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:25,902 : INFO : PROGRESS: at 46.90% examples, 35684 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:26,964 : INFO : PROGRESS: at 47.76% examples, 35689 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:28,015 : INFO : PROGRESS: at 48.61% examples, 35699 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:29,105 : INFO : PROGRESS: at 49.47% examples, 35689 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:30,160 : INFO : PROGRESS: at 50.33% examples, 35699 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:31,232 : INFO : PROGRESS: at 51.19% examples, 35696 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:32,274 : INFO : PROGRESS: at 52.04% examples, 35712 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:33,282 : INFO : PROGRESS: at 52.84% examples, 35707 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:34,345 : INFO : PROGRESS: at 53.70% examples, 35713 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:35,417 : INFO : PROGRESS: at 54.55% examples, 35713 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:36,476 : INFO : PROGRESS: at 55.41% examples, 35717 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:37,539 : INFO : PROGRESS: at 56.27% examples, 35726 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:38,625 : INFO : PROGRESS: at 57.12% examples, 35718 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:39,672 : INFO : PROGRESS: at 57.98% examples, 35729 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:40,767 : INFO : PROGRESS: at 58.84% examples, 35716 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:41,809 : INFO : PROGRESS: at 59.70% examples, 35729 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:42,917 : INFO : PROGRESS: at 60.55% examples, 35711 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:43,983 : INFO : PROGRESS: at 61.41% examples, 35713 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:45,051 : INFO : PROGRESS: at 62.27% examples, 35716 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:46,099 : INFO : PROGRESS: at 63.12% examples, 35726 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:47,176 : INFO : PROGRESS: at 63.98% examples, 35720 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:48,229 : INFO : PROGRESS: at 64.84% examples, 35730 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:49,310 : INFO : PROGRESS: at 65.70% examples, 35728 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:50,367 : INFO : PROGRESS: at 66.55% examples, 35733 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:51,453 : INFO : PROGRESS: at 67.41% examples, 35724 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:52,505 : INFO : PROGRESS: at 68.27% examples, 35734 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:53,613 : INFO : PROGRESS: at 69.12% examples, 35714 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:17:54,639 : INFO : PROGRESS: at 69.98% examples, 35730 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:55,757 : INFO : PROGRESS: at 70.84% examples, 35711 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:56,791 : INFO : PROGRESS: at 71.70% examples, 35724 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:57,878 : INFO : PROGRESS: at 72.55% examples, 35717 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:17:58,933 : INFO : PROGRESS: at 73.41% examples, 35722 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:00,008 : INFO : PROGRESS: at 74.27% examples, 35722 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:01,074 : INFO : PROGRESS: at 75.12% examples, 35723 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:02,145 : INFO : PROGRESS: at 75.98% examples, 35723 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:03,209 : INFO : PROGRESS: at 76.84% examples, 35725 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:04,281 : INFO : PROGRESS: at 77.70% examples, 35725 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:05,358 : INFO : PROGRESS: at 78.55% examples, 35722 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:06,418 : INFO : PROGRESS: at 79.41% examples, 35723 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:07,475 : INFO : PROGRESS: at 80.27% examples, 35730 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:08,541 : INFO : PROGRESS: at 81.12% examples, 35732 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:09,606 : INFO : PROGRESS: at 81.98% examples, 35733 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:10,648 : INFO : PROGRESS: at 82.84% examples, 35742 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:11,652 : INFO : PROGRESS: at 83.64% examples, 35736 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:12,656 : INFO : PROGRESS: at 84.43% examples, 35733 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:13,820 : INFO : PROGRESS: at 85.35% examples, 35726 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:14,864 : INFO : PROGRESS: at 86.27% examples, 35762 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:15,962 : INFO : PROGRESS: at 87.06% examples, 35728 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:16,989 : INFO : PROGRESS: at 87.98% examples, 35765 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:18,089 : INFO : PROGRESS: at 88.78% examples, 35731 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:19,110 : INFO : PROGRESS: at 89.64% examples, 35747 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:20,209 : INFO : PROGRESS: at 90.49% examples, 35737 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:21,232 : INFO : PROGRESS: at 91.35% examples, 35751 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:22,334 : INFO : PROGRESS: at 92.21% examples, 35742 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:23,346 : INFO : PROGRESS: at 93.06% examples, 35762 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:24,468 : INFO : PROGRESS: at 93.92% examples, 35743 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:25,471 : INFO : PROGRESS: at 94.78% examples, 35762 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:26,611 : INFO : PROGRESS: at 95.64% examples, 35742 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:27,660 : INFO : PROGRESS: at 96.55% examples, 35771 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:28,768 : INFO : PROGRESS: at 97.35% examples, 35736 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:29,795 : INFO : PROGRESS: at 98.27% examples, 35772 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:30,895 : INFO : PROGRESS: at 99.06% examples, 35741 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:31,790 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-02-23 14:18:31,836 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-02-23 14:18:31,849 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-02-23 14:18:31,857 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-02-23 14:18:31,858 : INFO : training on 16323600 raw words (4459097 effective words) took 124.6s, 35799 effective words/s
# 2017-02-23 14:18:32,077 : INFO : collecting all words and their counts
# 2017-02-23 14:18:32,078 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-02-23 14:18:32,234 : INFO : collected 10735 word types and 10000 unique tags from a corpus of 10000 examples and 108824 words
# 2017-02-23 14:18:32,235 : INFO : Loading a fresh vocabulary
# Completed run number 2 of 12 runs total
# AUC score: 0.7052
# Training for this run took 2.1 minutes
# 2017-02-23 14:18:32,299 : INFO : min_count=1 retains 10735 unique words (100% of original 10735, drops 0)
# 2017-02-23 14:18:32,300 : INFO : min_count=1 leaves 108824 word corpus (100% of original 108824, drops 0)
# 2017-02-23 14:18:32,384 : INFO : deleting the raw counts dictionary of 10735 items
# 2017-02-23 14:18:32,385 : INFO : sample=1e-06 downsamples 10735 most-common words
# 2017-02-23 14:18:32,387 : INFO : downsampling leaves estimated 7983 word corpus (7.3% of prior 108824)
# 2017-02-23 14:18:32,388 : INFO : estimated required memory for 10735 words and 300 dimensions: 45131500 bytes
# 2017-02-23 14:18:32,453 : INFO : resetting layer weights
# 2017-02-23 14:18:33,062 : INFO : training model with 4 workers on 10735 vocabulary and 300 features, using sg=1 hs=0 sample=1e-06 negative=5 window=5
# 2017-02-23 14:18:33,063 : INFO : expecting 10000 sentences, matching count from corpus used for vocabulary survey
# 2017-02-23 14:18:34,168 : INFO : PROGRESS: at 0.80% examples, 19614 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:35,257 : INFO : PROGRESS: at 1.78% examples, 22003 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:36,340 : INFO : PROGRESS: at 2.76% examples, 22758 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:37,413 : INFO : PROGRESS: at 3.74% examples, 23223 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:38,499 : INFO : PROGRESS: at 4.72% examples, 23472 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:39,581 : INFO : PROGRESS: at 5.70% examples, 23655 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:40,642 : INFO : PROGRESS: at 6.67% examples, 23826 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:41,721 : INFO : PROGRESS: at 7.66% examples, 23922 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:42,829 : INFO : PROGRESS: at 8.63% examples, 23911 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:43,917 : INFO : PROGRESS: at 9.62% examples, 23948 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:44,988 : INFO : PROGRESS: at 10.59% examples, 24016 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:45,992 : INFO : PROGRESS: at 11.51% examples, 24057 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:47,095 : INFO : PROGRESS: at 12.49% examples, 24046 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:48,215 : INFO : PROGRESS: at 13.47% examples, 24021 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:49,294 : INFO : PROGRESS: at 14.45% examples, 24041 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:50,372 : INFO : PROGRESS: at 15.43% examples, 24063 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:51,399 : INFO : PROGRESS: at 16.17% examples, 23801 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:52,458 : INFO : PROGRESS: at 16.90% examples, 23518 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:53,785 : INFO : PROGRESS: at 17.88% examples, 23282 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:54,847 : INFO : PROGRESS: at 18.61% examples, 23055 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:55,873 : INFO : PROGRESS: at 19.41% examples, 22954 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:56,934 : INFO : PROGRESS: at 20.08% examples, 22696 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:18:57,959 : INFO : PROGRESS: at 20.88% examples, 22625 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:18:59,014 : INFO : PROGRESS: at 21.55% examples, 22398 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:00,021 : INFO : PROGRESS: at 22.47% examples, 22481 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:01,047 : INFO : PROGRESS: at 23.27% examples, 22429 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:02,085 : INFO : PROGRESS: at 24.12% examples, 22420 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:03,105 : INFO : PROGRESS: at 24.98% examples, 22434 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:04,169 : INFO : PROGRESS: at 25.78% examples, 22354 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:05,205 : INFO : PROGRESS: at 26.45% examples, 22197 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:06,308 : INFO : PROGRESS: at 27.25% examples, 22111 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:07,338 : INFO : PROGRESS: at 28.17% examples, 22165 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:08,421 : INFO : PROGRESS: at 29.08% examples, 22190 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:09,541 : INFO : PROGRESS: at 30.06% examples, 22231 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:10,647 : INFO : PROGRESS: at 31.04% examples, 22284 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:11,672 : INFO : PROGRESS: at 31.90% examples, 22288 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:12,815 : INFO : PROGRESS: at 32.76% examples, 22231 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:13,832 : INFO : PROGRESS: at 33.49% examples, 22165 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:15,025 : INFO : PROGRESS: at 34.23% examples, 22006 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:16,062 : INFO : PROGRESS: at 35.14% examples, 22052 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:17,332 : INFO : PROGRESS: at 35.94% examples, 21900 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:18,342 : INFO : PROGRESS: at 36.67% examples, 21853 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:19,388 : INFO : PROGRESS: at 37.29% examples, 21715 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:20,469 : INFO : PROGRESS: at 38.14% examples, 21708 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:21,579 : INFO : PROGRESS: at 39.12% examples, 21757 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:22,676 : INFO : PROGRESS: at 40.10% examples, 21809 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:23,779 : INFO : PROGRESS: at 41.08% examples, 21858 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:24,861 : INFO : PROGRESS: at 42.06% examples, 21910 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:25,891 : INFO : PROGRESS: at 42.98% examples, 21959 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:27,004 : INFO : PROGRESS: at 43.78% examples, 21902 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:28,025 : INFO : PROGRESS: at 44.63% examples, 21914 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:29,131 : INFO : PROGRESS: at 45.49% examples, 21894 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:30,156 : INFO : PROGRESS: at 46.29% examples, 21878 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:31,196 : INFO : PROGRESS: at 47.08% examples, 21854 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:32,274 : INFO : PROGRESS: at 48.00% examples, 21877 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:33,298 : INFO : PROGRESS: at 48.80% examples, 21860 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:34,440 : INFO : PROGRESS: at 49.72% examples, 21859 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:35,500 : INFO : PROGRESS: at 50.57% examples, 21859 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:36,597 : INFO : PROGRESS: at 51.43% examples, 21847 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:37,625 : INFO : PROGRESS: at 52.23% examples, 21833 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:38,647 : INFO : PROGRESS: at 52.84% examples, 21743 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:39,653 : INFO : PROGRESS: at 53.51% examples, 21687 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:40,732 : INFO : PROGRESS: at 54.25% examples, 21636 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:41,854 : INFO : PROGRESS: at 54.92% examples, 21547 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:42,954 : INFO : PROGRESS: at 55.66% examples, 21495 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:43,969 : INFO : PROGRESS: at 56.39% examples, 21463 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:45,025 : INFO : PROGRESS: at 57.12% examples, 21423 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:46,044 : INFO : PROGRESS: at 57.74% examples, 21349 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:47,061 : INFO : PROGRESS: at 58.53% examples, 21347 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:48,083 : INFO : PROGRESS: at 59.39% examples, 21364 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:49,109 : INFO : PROGRESS: at 60.00% examples, 21294 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:50,227 : INFO : PROGRESS: at 60.67% examples, 21224 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:51,365 : INFO : PROGRESS: at 61.41% examples, 21169 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:52,484 : INFO : PROGRESS: at 62.21% examples, 21142 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:53,539 : INFO : PROGRESS: at 63.06% examples, 21151 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:54,541 : INFO : PROGRESS: at 63.74% examples, 21113 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:55,551 : INFO : PROGRESS: at 64.47% examples, 21095 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:56,653 : INFO : PROGRESS: at 65.21% examples, 21056 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:57,696 : INFO : PROGRESS: at 65.94% examples, 21030 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:19:58,783 : INFO : PROGRESS: at 66.67% examples, 20994 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:19:59,821 : INFO : PROGRESS: at 67.41% examples, 20972 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:00,846 : INFO : PROGRESS: at 68.14% examples, 20954 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:01,878 : INFO : PROGRESS: at 68.94% examples, 20953 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:02,879 : INFO : PROGRESS: at 69.62% examples, 20922 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:03,949 : INFO : PROGRESS: at 70.35% examples, 20895 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:04,950 : INFO : PROGRESS: at 70.90% examples, 20828 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:06,005 : INFO : PROGRESS: at 71.51% examples, 20769 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:07,070 : INFO : PROGRESS: at 72.19% examples, 20728 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:08,075 : INFO : PROGRESS: at 72.80% examples, 20682 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:09,222 : INFO : PROGRESS: at 73.41% examples, 20607 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:10,227 : INFO : PROGRESS: at 74.02% examples, 20564 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:11,255 : INFO : PROGRESS: at 74.57% examples, 20499 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:12,320 : INFO : PROGRESS: at 75.37% examples, 20494 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:13,345 : INFO : PROGRESS: at 76.29% examples, 20533 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:14,371 : INFO : PROGRESS: at 77.21% examples, 20569 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:15,467 : INFO : PROGRESS: at 78.19% examples, 20607 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:16,573 : INFO : PROGRESS: at 79.17% examples, 20642 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:17,677 : INFO : PROGRESS: at 80.14% examples, 20676 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:18,778 : INFO : PROGRESS: at 81.12% examples, 20712 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:19,860 : INFO : PROGRESS: at 82.10% examples, 20749 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:20,942 : INFO : PROGRESS: at 83.08% examples, 20788 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:22,032 : INFO : PROGRESS: at 84.06% examples, 20822 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:23,126 : INFO : PROGRESS: at 85.04% examples, 20855 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:24,212 : INFO : PROGRESS: at 86.02% examples, 20889 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:25,310 : INFO : PROGRESS: at 87.00% examples, 20921 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:26,378 : INFO : PROGRESS: at 87.98% examples, 20958 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:27,469 : INFO : PROGRESS: at 88.96% examples, 20990 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:28,526 : INFO : PROGRESS: at 89.94% examples, 21026 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:29,631 : INFO : PROGRESS: at 90.92% examples, 21053 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:30,725 : INFO : PROGRESS: at 91.90% examples, 21082 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:31,823 : INFO : PROGRESS: at 92.88% examples, 21110 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:32,914 : INFO : PROGRESS: at 93.86% examples, 21138 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:34,010 : INFO : PROGRESS: at 94.84% examples, 21166 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:35,083 : INFO : PROGRESS: at 95.82% examples, 21199 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:36,175 : INFO : PROGRESS: at 96.80% examples, 21225 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:37,251 : INFO : PROGRESS: at 97.78% examples, 21254 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:38,342 : INFO : PROGRESS: at 98.76% examples, 21281 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:39,395 : INFO : PROGRESS: at 99.74% examples, 21312 words/s, in_qsize 5, out_qsize 0
# 2017-02-23 14:20:39,511 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-02-23 14:20:39,541 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-02-23 14:20:39,544 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-02-23 14:20:39,564 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-02-23 14:20:39,565 : INFO : training on 16323600 raw words (2699389 effective words) took 126.5s, 21340 effective words/s
# 2017-02-23 14:20:39,777 : INFO : collecting all words and their counts
# 2017-02-23 14:20:39,779 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-02-23 14:20:39,907 : INFO : collected 10735 word types and 10000 unique tags from a corpus of 10000 examples and 108824 words
# 2017-02-23 14:20:39,908 : INFO : Loading a fresh vocabulary
# 2017-02-23 14:20:39,937 : INFO : min_count=5 retains 2343 unique words (21% of original 10735, drops 8392)
# 2017-02-23 14:20:39,939 : INFO : min_count=5 leaves 94878 word corpus (87% of original 108824, drops 13946)
# 2017-02-23 14:20:39,961 : INFO : deleting the raw counts dictionary of 10735 items
# 2017-02-23 14:20:39,963 : INFO : sample=1e-05 downsamples 2343 most-common words
# 2017-02-23 14:20:39,964 : INFO : downsampling leaves estimated 12141 word corpus (12.8% of prior 94878)
# 2017-02-23 14:20:39,965 : INFO : estimated required memory for 2343 words and 300 dimensions: 20794700 bytes
# Completed run number 3 of 12 runs total
# AUC score: 0.3493
# Training for this run took 2.1 minutes
# 2017-02-23 14:20:39,980 : INFO : resetting layer weights
# 2017-02-23 14:20:40,379 : INFO : training model with 4 workers on 2343 vocabulary and 300 features, using sg=1 hs=0 sample=1e-05 negative=5 window=5
# 2017-02-23 14:20:40,381 : INFO : expecting 10000 sentences, matching count from corpus used for vocabulary survey
# 2017-02-23 14:20:41,538 : INFO : PROGRESS: at 0.80% examples, 23341 words/s, in_qsize 7, out_qsize 1
# 2017-02-23 14:20:42,649 : INFO : PROGRESS: at 1.78% examples, 26257 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:43,782 : INFO : PROGRESS: at 2.76% examples, 27043 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:44,905 : INFO : PROGRESS: at 3.74% examples, 27498 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:46,026 : INFO : PROGRESS: at 4.72% examples, 27802 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:47,139 : INFO : PROGRESS: at 5.70% examples, 28032 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:48,244 : INFO : PROGRESS: at 6.67% examples, 28226 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:49,352 : INFO : PROGRESS: at 7.66% examples, 28374 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:50,464 : INFO : PROGRESS: at 8.63% examples, 28490 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:51,579 : INFO : PROGRESS: at 9.62% examples, 28569 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:52,684 : INFO : PROGRESS: at 10.59% examples, 28649 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:53,813 : INFO : PROGRESS: at 11.57% examples, 28647 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:20:54,918 : INFO : PROGRESS: at 12.55% examples, 28689 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:56,026 : INFO : PROGRESS: at 13.53% examples, 28739 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:57,135 : INFO : PROGRESS: at 14.51% examples, 28770 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:58,253 : INFO : PROGRESS: at 15.49% examples, 28781 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:20:59,370 : INFO : PROGRESS: at 16.47% examples, 28801 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:00,487 : INFO : PROGRESS: at 17.45% examples, 28824 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:01,591 : INFO : PROGRESS: at 18.43% examples, 28859 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:02,707 : INFO : PROGRESS: at 19.41% examples, 28872 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:03,814 : INFO : PROGRESS: at 20.39% examples, 28902 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:04,942 : INFO : PROGRESS: at 21.37% examples, 28904 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:06,051 : INFO : PROGRESS: at 22.35% examples, 28924 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:07,175 : INFO : PROGRESS: at 23.33% examples, 28931 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:08,289 : INFO : PROGRESS: at 24.31% examples, 28948 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:09,391 : INFO : PROGRESS: at 25.29% examples, 28969 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:10,511 : INFO : PROGRESS: at 26.27% examples, 28976 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:11,627 : INFO : PROGRESS: at 27.25% examples, 28981 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:12,764 : INFO : PROGRESS: at 28.23% examples, 28967 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:13,891 : INFO : PROGRESS: at 29.21% examples, 28970 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:15,007 : INFO : PROGRESS: at 30.19% examples, 28968 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:16,115 : INFO : PROGRESS: at 31.17% examples, 28981 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:17,119 : INFO : PROGRESS: at 32.08% examples, 29020 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:18,145 : INFO : PROGRESS: at 33.00% examples, 29043 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:19,166 : INFO : PROGRESS: at 33.86% examples, 29009 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:20,205 : INFO : PROGRESS: at 34.78% examples, 29016 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:21,304 : INFO : PROGRESS: at 35.76% examples, 29031 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:22,339 : INFO : PROGRESS: at 36.67% examples, 29039 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:23,408 : INFO : PROGRESS: at 37.59% examples, 29030 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:24,444 : INFO : PROGRESS: at 38.51% examples, 29041 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:25,446 : INFO : PROGRESS: at 39.37% examples, 29029 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:26,462 : INFO : PROGRESS: at 40.29% examples, 29055 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:27,512 : INFO : PROGRESS: at 41.21% examples, 29052 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:28,537 : INFO : PROGRESS: at 42.06% examples, 29021 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:29,655 : INFO : PROGRESS: at 43.04% examples, 29023 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:30,762 : INFO : PROGRESS: at 44.02% examples, 29032 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:31,894 : INFO : PROGRESS: at 45.00% examples, 29024 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:32,899 : INFO : PROGRESS: at 45.92% examples, 29048 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:21:33,934 : INFO : PROGRESS: at 46.84% examples, 29053 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:21:34,963 : INFO : PROGRESS: at 47.70% examples, 29026 words/s, in_qsize 7, out_qsize 0
# ...
# 2017-02-23 14:37:13,811 : INFO : PROGRESS: at 78.86% examples, 20611 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:14,989 : INFO : PROGRESS: at 79.84% examples, 20635 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:16,144 : INFO : PROGRESS: at 80.82% examples, 20660 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:17,311 : INFO : PROGRESS: at 81.80% examples, 20683 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:18,456 : INFO : PROGRESS: at 82.78% examples, 20710 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:19,603 : INFO : PROGRESS: at 83.76% examples, 20737 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:20,749 : INFO : PROGRESS: at 84.74% examples, 20764 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:21,912 : INFO : PROGRESS: at 85.72% examples, 20786 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:23,035 : INFO : PROGRESS: at 86.69% examples, 20814 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:24,163 : INFO : PROGRESS: at 87.68% examples, 20841 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:25,307 : INFO : PROGRESS: at 88.65% examples, 20866 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:26,461 : INFO : PROGRESS: at 89.64% examples, 20887 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:27,578 : INFO : PROGRESS: at 90.61% examples, 20914 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:28,586 : INFO : PROGRESS: at 91.53% examples, 20947 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:29,707 : INFO : PROGRESS: at 92.39% examples, 20947 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:30,716 : INFO : PROGRESS: at 93.31% examples, 20977 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:31,757 : INFO : PROGRESS: at 94.23% examples, 21002 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:32,830 : INFO : PROGRESS: at 95.08% examples, 21008 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:33,837 : INFO : PROGRESS: at 96.00% examples, 21039 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:34,883 : INFO : PROGRESS: at 96.80% examples, 21035 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:35,908 : INFO : PROGRESS: at 97.72% examples, 21062 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:36,938 : INFO : PROGRESS: at 98.57% examples, 21076 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:38,016 : INFO : PROGRESS: at 99.49% examples, 21092 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:38,356 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-02-23 14:37:38,375 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-02-23 14:37:38,389 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-02-23 14:37:38,414 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-02-23 14:37:38,415 : INFO : training on 16323600 raw words (2718994 effective words) took 128.7s, 21135 effective words/s
# 2017-02-23 14:37:38,628 : INFO : collecting all words and their counts
# 2017-02-23 14:37:38,629 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-02-23 14:37:38,794 : INFO : collected 10735 word types and 10000 unique tags from a corpus of 10000 examples and 108824 words
# 2017-02-23 14:37:38,795 : INFO : Loading a fresh vocabulary
# 2017-02-23 14:37:38,828 : INFO : min_count=5 retains 2343 unique words (21% of original 10735, drops 8392)
# Completed run number 11 of 12 runs total
# AUC score: 0.5567
# Training for this run took 2.2 minutes
# 2017-02-23 14:37:38,829 : INFO : min_count=5 leaves 94878 word corpus (87% of original 108824, drops 13946)
# 2017-02-23 14:37:38,856 : INFO : deleting the raw counts dictionary of 10735 items
# 2017-02-23 14:37:38,858 : INFO : sample=1e-06 downsamples 2343 most-common words
# 2017-02-23 14:37:38,860 : INFO : downsampling leaves estimated 3358 word corpus (3.5% of prior 94878)
# 2017-02-23 14:37:38,861 : INFO : estimated required memory for 2343 words and 300 dimensions: 20794700 bytes
# 2017-02-23 14:37:38,884 : INFO : resetting layer weights
# 2017-02-23 14:37:39,268 : INFO : training model with 4 workers on 2343 vocabulary and 300 features, using sg=1 hs=0 sample=1e-06 negative=5 window=15
# 2017-02-23 14:37:39,269 : INFO : expecting 10000 sentences, matching count from corpus used for vocabulary survey
# 2017-02-23 14:37:40,338 : INFO : PROGRESS: at 0.80% examples, 15046 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:41,379 : INFO : PROGRESS: at 1.78% examples, 16979 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:42,421 : INFO : PROGRESS: at 2.76% examples, 17559 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:43,472 : INFO : PROGRESS: at 3.74% examples, 17845 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:44,543 : INFO : PROGRESS: at 4.72% examples, 17929 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:45,609 : INFO : PROGRESS: at 5.70% examples, 18017 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:46,696 : INFO : PROGRESS: at 6.67% examples, 18016 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:47,755 : INFO : PROGRESS: at 7.66% examples, 18081 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:48,828 : INFO : PROGRESS: at 8.63% examples, 18122 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:49,910 : INFO : PROGRESS: at 9.62% examples, 18130 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:50,975 : INFO : PROGRESS: at 10.59% examples, 18149 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:52,058 : INFO : PROGRESS: at 11.57% examples, 18141 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:53,117 : INFO : PROGRESS: at 12.55% examples, 18170 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:54,186 : INFO : PROGRESS: at 13.53% examples, 18189 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:55,247 : INFO : PROGRESS: at 14.51% examples, 18209 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:56,336 : INFO : PROGRESS: at 15.49% examples, 18197 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:37:57,397 : INFO : PROGRESS: at 16.47% examples, 18219 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:58,455 : INFO : PROGRESS: at 17.45% examples, 18244 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:37:59,472 : INFO : PROGRESS: at 18.25% examples, 18121 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:00,481 : INFO : PROGRESS: at 19.10% examples, 18078 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:01,564 : INFO : PROGRESS: at 20.08% examples, 18075 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:02,627 : INFO : PROGRESS: at 21.06% examples, 18089 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:03,705 : INFO : PROGRESS: at 22.04% examples, 18097 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:04,773 : INFO : PROGRESS: at 23.02% examples, 18113 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:05,868 : INFO : PROGRESS: at 24.00% examples, 18107 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:06,950 : INFO : PROGRESS: at 24.98% examples, 18109 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:08,021 : INFO : PROGRESS: at 25.96% examples, 18116 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:09,078 : INFO : PROGRESS: at 26.94% examples, 18132 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:10,156 : INFO : PROGRESS: at 27.92% examples, 18135 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:11,246 : INFO : PROGRESS: at 28.90% examples, 18136 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:12,313 : INFO : PROGRESS: at 29.88% examples, 18142 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:13,363 : INFO : PROGRESS: at 30.86% examples, 18157 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:14,426 : INFO : PROGRESS: at 31.84% examples, 18164 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:15,555 : INFO : PROGRESS: at 32.76% examples, 18107 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:16,618 : INFO : PROGRESS: at 33.55% examples, 18019 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:17,667 : INFO : PROGRESS: at 34.29% examples, 17909 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:18,745 : INFO : PROGRESS: at 35.27% examples, 17914 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:19,795 : INFO : PROGRESS: at 36.19% examples, 17902 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:20,840 : INFO : PROGRESS: at 36.98% examples, 17834 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:21,879 : INFO : PROGRESS: at 37.90% examples, 17832 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:22,890 : INFO : PROGRESS: at 38.82% examples, 17838 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:24,023 : INFO : PROGRESS: at 39.68% examples, 17770 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:25,053 : INFO : PROGRESS: at 40.59% examples, 17769 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:26,134 : INFO : PROGRESS: at 41.39% examples, 17699 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:27,205 : INFO : PROGRESS: at 42.37% examples, 17714 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:28,330 : INFO : PROGRESS: at 43.35% examples, 17709 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:29,427 : INFO : PROGRESS: at 44.33% examples, 17713 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:30,528 : INFO : PROGRESS: at 45.31% examples, 17711 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:31,632 : INFO : PROGRESS: at 46.04% examples, 17619 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:32,647 : INFO : PROGRESS: at 46.90% examples, 17605 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:33,767 : INFO : PROGRESS: at 47.76% examples, 17557 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:34,835 : INFO : PROGRESS: at 48.67% examples, 17548 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:35,974 : INFO : PROGRESS: at 49.47% examples, 17477 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:37,090 : INFO : PROGRESS: at 50.45% examples, 17480 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:38,146 : INFO : PROGRESS: at 51.43% examples, 17499 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:39,157 : INFO : PROGRESS: at 52.29% examples, 17491 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:40,166 : INFO : PROGRESS: at 53.02% examples, 17444 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:41,220 : INFO : PROGRESS: at 53.82% examples, 17406 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:42,306 : INFO : PROGRESS: at 54.80% examples, 17415 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:43,350 : INFO : PROGRESS: at 55.78% examples, 17437 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:44,419 : INFO : PROGRESS: at 56.76% examples, 17453 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:45,479 : INFO : PROGRESS: at 57.74% examples, 17469 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:46,506 : INFO : PROGRESS: at 58.72% examples, 17495 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:47,511 : INFO : PROGRESS: at 59.51% examples, 17472 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:48,647 : INFO : PROGRESS: at 60.49% examples, 17468 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:49,774 : INFO : PROGRESS: at 61.47% examples, 17468 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:50,891 : INFO : PROGRESS: at 62.45% examples, 17469 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:51,967 : INFO : PROGRESS: at 63.43% examples, 17481 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:53,038 : INFO : PROGRESS: at 64.41% examples, 17493 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:54,110 : INFO : PROGRESS: at 65.39% examples, 17505 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:38:55,264 : INFO : PROGRESS: at 66.37% examples, 17498 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:56,278 : INFO : PROGRESS: at 67.23% examples, 17491 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:57,305 : INFO : PROGRESS: at 68.08% examples, 17481 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:58,368 : INFO : PROGRESS: at 69.06% examples, 17495 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:38:59,441 : INFO : PROGRESS: at 70.04% examples, 17505 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:00,570 : INFO : PROGRESS: at 71.02% examples, 17505 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:01,580 : INFO : PROGRESS: at 71.76% examples, 17469 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:02,617 : INFO : PROGRESS: at 72.67% examples, 17472 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:03,619 : INFO : PROGRESS: at 73.47% examples, 17453 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:04,640 : INFO : PROGRESS: at 74.39% examples, 17462 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:05,706 : INFO : PROGRESS: at 75.37% examples, 17473 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:39:06,714 : INFO : PROGRESS: at 76.29% examples, 17482 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:39:07,718 : INFO : PROGRESS: at 77.14% examples, 17479 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:08,829 : INFO : PROGRESS: at 78.12% examples, 17480 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:09,833 : INFO : PROGRESS: at 78.98% examples, 17476 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:10,876 : INFO : PROGRESS: at 79.84% examples, 17464 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:39:11,938 : INFO : PROGRESS: at 80.76% examples, 17463 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:12,946 : INFO : PROGRESS: at 81.68% examples, 17473 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:14,014 : INFO : PROGRESS: at 82.65% examples, 17483 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:39:15,066 : INFO : PROGRESS: at 83.64% examples, 17496 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:16,167 : INFO : PROGRESS: at 84.61% examples, 17498 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:17,292 : INFO : PROGRESS: at 85.59% examples, 17497 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:39:18,355 : INFO : PROGRESS: at 86.57% examples, 17507 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:19,454 : INFO : PROGRESS: at 87.49% examples, 17498 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:39:20,542 : INFO : PROGRESS: at 88.29% examples, 17468 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:21,551 : INFO : PROGRESS: at 89.21% examples, 17474 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:22,554 : INFO : PROGRESS: at 90.00% examples, 17459 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:23,593 : INFO : PROGRESS: at 90.74% examples, 17426 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:24,667 : INFO : PROGRESS: at 91.72% examples, 17435 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:25,750 : INFO : PROGRESS: at 92.69% examples, 17442 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:26,830 : INFO : PROGRESS: at 93.68% examples, 17449 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:27,906 : INFO : PROGRESS: at 94.65% examples, 17457 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:28,995 : INFO : PROGRESS: at 95.64% examples, 17463 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:39:30,055 : INFO : PROGRESS: at 96.61% examples, 17472 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:31,129 : INFO : PROGRESS: at 97.59% examples, 17479 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:32,197 : INFO : PROGRESS: at 98.57% examples, 17486 words/s, in_qsize 7, out_qsize 0
# 2017-02-23 14:39:33,272 : INFO : PROGRESS: at 99.55% examples, 17494 words/s, in_qsize 8, out_qsize 0
# 2017-02-23 14:39:33,540 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-02-23 14:39:33,547 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-02-23 14:39:33,566 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-02-23 14:39:33,575 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-02-23 14:39:33,576 : INFO : training on 16323600 raw words (2003229 effective words) took 114.3s, 17526 effective words/s
# Completed run number 12 of 12 runs total
# AUC score: 0.4654
# Training for this run took 1.9 minutes
#
#
# Total training time for all runs: 0.03 hours
# Best AUC value: 0.712672
# Paramters for best AUC value: {'dm': 0, 'hs': 0, 'sample': 1e-05, 'dbow_words': 1, 'alpha': 0.025, 'min_count': 1, 'size': 300, 'workers': 4, 'negative': 5, 'iter': 150, 'window': 5, 'min_alpha': 0.0001}

# %%
params_df
# Out:
#     alpha  dbow_words  dm  hs  iter  min_alpha  min_count  negative    sample  \
# 0   0.025           1   0   0   150     0.0001          1         5  0.000010
# 1   0.025           1   0   0   150     0.0001          1         5  0.000005
# 6   0.025           1   0   0   150     0.0001          1         5  0.000010
# 7   0.025           1   0   0   150     0.0001          1         5  0.000005
# 9   0.025           1   0   0   150     0.0001          5         5  0.000010
# 3   0.025           1   0   0   150     0.0001          5         5  0.000010
# 4   0.025           1   0   0   150     0.0001          5         5  0.000005
# 10  0.025           1   0   0   150     0.0001          5         5  0.000005
# 11  0.025           1   0   0   150     0.0001          5         5  0.000001
# 5   0.025           1   0   0   150     0.0001          5         5  0.000001
# 2   0.025           1   0   0   150     0.0001          1         5  0.000001
# 8   0.025           1   0   0   150     0.0001          1         5  0.000001
#
#     size  window  workers       AUC
# 0    300       5        4  0.712672
# 1    300       5        4  0.705181
# 6    300      15        4  0.698711
# 7    300      15        4  0.697390
# 9    300      15        4  0.655480
# 3    300       5        4  0.641993
# 4    300       5        4  0.556895
# 10   300      15        4  0.556657
# 11   300      15        4  0.465403
# 5    300       5        4  0.462598
# 2    300       5        4  0.349286
# 8    300      15        4  0.347445

# %%
# show only the columns that changed in value 
params_df.loc[:, (params_df != params_df.ix[0]).any()]
# Out:
#     min_count    sample  window       AUC
# 0           1  0.000010       5  0.712672
# 1           1  0.000005       5  0.705181
# 6           1  0.000010      15  0.698711
# 7           1  0.000005      15  0.697390
# 9           5  0.000010      15  0.655480
# 3           5  0.000010       5  0.641993
# 4           5  0.000005       5  0.556895
# 10          5  0.000005      15  0.556657
# 11          5  0.000001      15  0.465403
# 5           5  0.000001       5  0.462598
# 2           1  0.000001       5  0.349286
# 8           1  0.000001      15  0.347445

# %%
""" PARAMETER TIPS: 

sample: CRITICAL: 1e-6 terrible, 5e-6 and 1e-5 better - try 5e-5 
min_count: 1 works well with small data set
window: 5 and 15 both worked reasonably well
size: 300 works well
iter: 150 seems ok, try more - sentence similarity in paper used ~400 to converge






"""

# %%
# read in paramater file to see what has been done before
all_params_df = pd.read_csv(parameters_and_errors_name)

# %%
all_params_df
# Out:
#    alpha  dbow_words  dm  hs  iter  min_alpha  min_count  negative   sample  \
# 0  0.025           1   0   0   100     0.0001         10         5  0.00001
# 1  0.025           1   0   0   100     0.0001         10         5  0.00001
# 2  0.025           1   0   0   100     0.0001          5         5  0.00001
# 3  0.025           1   0   0   100     0.0001         10         5  0.00001
# 4  0.025           1   0   0   100     0.0001          5         5  0.00001
# 5  0.025           1   0   0   100     0.0001          5         5  0.00001
#
#    size  window  workers       AUC
# 0   300      15        4  0.737806
# 1   100      15        4  0.737249
# 2   100      15        4  0.737077
# 3   200      15        4  0.737076
# 4   200      15        4  0.736904
# 5   300      15        4  0.736056

# %%
# 0.672 with 100-length vectors and 20 epochs
# 0.671 with 300-length vectors and 20 epochs
# 0.74 with 200-length vectors and 200 epochs
# 0.74 with 200-length vectors and 100 epochs

# model seems to tail off in accuracy around 100 epochs

# %% [markdown]
# # Manual runs with accuracy check at each epoch

# %%
# try a run with manual epochs and recording accuracy after each epoch
model = gensim.models.doc2vec.Doc2Vec(documents=None, dm=dm, size=size, window=window, 
                                      alpha=alpha, min_alpha=min_alpha, min_count=min_count, 
                                      sample=sample, workers=workers, hs=hs, negative=negative, 
                                      dbow_words=dbow_words, iter=1)

# %%
from random import shuffle

# number of epochs to train
# need to manually decrease alpha in this case
epochs = 100
alpha = 0.025
min_alpha = 0.0001
alpha_delta = (alpha - min_alpha) / epochs

model.build_vocab(all_docs)
with elapsed_timer() as elapsed:
    for epoch in range(epochs): 
        model.alpha, model.min_alpha = alpha, alpha
        # shuffle documents
        shuffle(all_docs)
        # train model
        model.train(all_docs)
        # evaluate model 
        error = calculate_AUC(model, doc_names_and_duplicate_class)
        alpha -= alpha_delta
        print "AUC for epoch", epoch, ":", error
    duration = '%.1f' % elapsed()
    print("completed training in %s minutes" % (duration/60.))
